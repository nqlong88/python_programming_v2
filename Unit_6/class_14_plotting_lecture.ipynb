# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
plt.plot(x, y)

# %%
#multiple sub plots

plt.figure()

plt.subplot(1, 2, 1) #subplot 1
plt.plot(x, y)

plt.subplot(1,2,2) #aubplot 2
plt.plot(y, x)
plt.show()

# %%
#starting with a blank canvas

fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
#plot a bar graph

plt.bar(x, y, width=0.5, align="center")
# Out:
# <BarContainer object of 11 artists>

# %%
#plotting a histogram
grades = [1, 2, 1, 1, 3, 3, 1, 2, 2, 1, 1, 3, 2, 1, 5]
data = np.array(grades)

# %%
data
# Out:
# array([15, 27, 65, 80,  9])

# %%
plt.hist(data, bins=7)
plt.hist()
# Out:
# (array([7., 4., 0., 3., 0., 0., 1.]),
#  array([1.        , 1.57142857, 2.14285714, 2.71428571, 3.28571429,
#         3.85714286, 4.42857143, 5.        ]),
#  <a list of 7 Patch objects>)

# %%
#boxplot
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11f4b2e10>,
#   <matplotlib.lines.Line2D at 0x11f4708d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11f539710>,
#   <matplotlib.lines.Line2D at 0x11f539c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11f533090>],
#  'medians': [<matplotlib.lines.Line2D at 0x11f533d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11f4a6510>],
#  'means': []}
