# %%
#RSM2130 - Rotman: Real Estate Investment Hedonics Data Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
hedonics = pd.read_csv(r'C:\Users\longn\Python_programming\Unit_6\Practice\RSM2130data4project.csv')

# %%
hedonics.shape
# Out:
# (21480, 18)

# %%
hedonics.columns
# Out:
# Index(['bedrooms', 'days_on_market', 'fireplace', 'price_sold', 'year',
#        'yearbuilt', 'zipcode', 'baths', 'lotsize', 'pool', 'sqft', 'style',
#        'type', 'heattype', 'basement', 'latitude', 'longitude', 'school_dist'],
#       dtype='object')

# %%
hedonics.head()
# Out:
#    bedrooms  days_on_market  fireplace  price_sold  year  yearbuilt  zipcode  \
# 0       3.0             7.0        1.0      186000  2004       1994    30043
# 1       3.0            83.0        1.0      157000  2004       1994    30047
# 2       3.0            33.0        1.0      123913  2004       1998    30045
# 3       5.0            84.0        1.0      162800  2004       2002    30045
# 4       3.0           117.0        1.0      133000  2004       1972    30044
#
#    baths          lotsize   pool  sqft  style   type     heattype  \
# 0    2.0  1/3 to 1/2 Acre  None_   NaN  Ranch    Res  FORCE,GAS__
# 1    2.0   Under 1/2 Acre  None_   NaN  Other  Resid        GAS__
# 2    2.0  1/3 to 1/2 Acre  None_   NaN  Ranch  Resid  FORCE,GAS__
# 3    3.0   Under 1/3 Acre  None_   NaN  Ranch  Resid        GAS__
# 4    2.0  1/3 to 1/2 Acre  None_   NaN  Tradt    Res  FORCE,GAS__
#
#       basement   latitude  longitude  school_dist
# 0        SLABN  43.993904 -74.056923         33.0
# ...

# %%
hedonics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21480 entries, 0 to 21479
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bedrooms        16810 non-null  float64
#  1   days_on_market  21480 non-null  float64
#  2   fireplace       16878 non-null  float64
#  3   price_sold      21480 non-null  int64
#  4   year            21480 non-null  int64
#  5   yearbuilt       21480 non-null  int64
#  6   zipcode         21480 non-null  int64
#  7   baths           16810 non-null  float64
#  8   lotsize         16615 non-null  object
#  9   pool            15926 non-null  object
#  10  sqft            0 non-null      float64
#  11  style           21106 non-null  object
#  12  type            19012 non-null  object
#  13  heattype        16986 non-null  object
#  14  basement        16749 non-null  object
#  15  latitude        17484 non-null  float64
#  16  longitude       17484 non-null  float64
# ...

# %%
hedonics.describe()
# Out:
#            bedrooms  days_on_market     fireplace    price_sold          year  \
# count  16810.000000    21480.000000  16878.000000  2.148000e+04  21480.000000
# mean       3.642296       81.646395      3.476715  1.823485e+05   2006.177933
# std        0.838501       78.612488     44.228281  7.666158e+04      1.607022
# min        0.000000        0.000000      0.000000  2.100000e+04   2004.000000
# 25%        3.000000       28.000000      1.000000  1.400000e+05   2005.000000
# 50%        4.000000       61.000000      1.000000  1.660000e+05   2006.000000
# 75%        4.000000      108.000000      1.000000  2.050000e+05   2007.000000
# max       10.000000     1035.000000   1745.000000  2.234825e+06   2009.000000
#
#           yearbuilt       zipcode         baths  sqft      latitude  \
# count  21480.000000  21480.000000  16810.000000   0.0  17484.000000
# mean    2023.001629  30028.378631      2.276026   NaN     43.956974
# ...

# %%
#run plots
sns.pairplot(hedonics)

# %%
sns.distplot(hedonics['ln_price_sold'])

# %%
hedonics.corr()
# Out:
#                 bedrooms  days_on_market  fireplace  price_sold      year  \
# bedrooms        1.000000        0.020547   0.199659    0.541668 -0.004915
# days_on_market  0.020547        1.000000  -0.023566    0.116844  0.072862
# fireplace       0.199659       -0.023566   1.000000    0.024452 -0.017023
# price_sold      0.541668        0.116844   0.024452    1.000000 -0.133926
# year           -0.004915        0.072862  -0.017023   -0.133926  1.000000
# yearbuilt      -0.008180       -0.000360  -0.004896    0.017482 -0.022033
# zipcode        -0.006649        0.009938   0.001591   -0.000849 -0.013289
# baths           0.640243        0.053073   0.255842    0.580634  0.021940
# sqft                 NaN             NaN        NaN         NaN       NaN
# latitude        0.058562       -0.013643  -0.017917    0.114445 -0.010824
# longitude       0.192768        0.055138  -0.021216    0.168025  0.026170
# school_dist     0.110793       -0.006678   0.024165    0.075472 -0.025834
#
# ...

# %%
sns.heatmap(hedonics.corr(), annot = True)
#seems that: bedroom & bathroom has highest correlation w price sold

# %%
#need to create ln(price_sold): Use numpy
hedonics['ln_price_sold'] = np.log(hedonics['price_sold'])

# %%
hedonics.tail()
# Out:
#        bedrooms  days_on_market  fireplace  price_sold  year  yearbuilt  \
# 21475       3.0            11.0        1.0       84000  2009       1972
# 21476       4.0            76.0        1.0      230000  2009       1986
# 21477       3.0            18.0        1.0      165800  2009       1998
# 21478       4.0             6.0        0.0      204900  2009       2006
# 21479       3.0            10.0        1.0       60100  2009       1983
#
#        zipcode  baths           lotsize  pool  sqft        style type  \
# 21475    30044    2.0  1/2 To 3/4 Acres  None   NaN  Traditional  NaN
# 21476    30044    2.0   1/3 To 1/2 Acre  None   NaN  Traditional  NaN
# 21477    30043    2.0    Under 1/3 Acre  None   NaN  Traditional  NaN
# 21478    30043    2.0    Under 1/3 Acre  None   NaN  Traditional  NaN
# 21479    30044    2.0   1/3 To 1/2 Acre  None   NaN  Traditional  NaN
#
#                 heattype                       basement   latitude  longitude  \
# ...

# %%
#1. Describe and run a hedonic regression for this market. In particular, what would be the dependent 
#and independent variables you would include.

# %%
#Took out certain non-int values (strings) -> Update: need to create dummies for these variables to include them
X = hedonics[['bedrooms','baths']]

# %%
y = hedonics['price_sold']

# %%
#import auto train split algo:
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size = 0.4, random_state=101)

# %%
#import linear regression model:

from sklearn.linear_model import LinearRegression #this is a Class

# %%
house_price = LinearRegression()

# %%
house_price.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-89368c6ab839> in <module>
# ----> 1 house_price.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# ...

# %%
#2. What would be the key factor that is of your interest? How do you think this factor would affect the property value?




#3. Discuss the problem of omitted variables in your regression. What factors might be omitted and 
#why would this bias your results.





#4. Optional question: A Lasso Regression helps with the process of reducing the number of
#explanatory coefficients in order to simplify the model, reduce the error, and increase the
#predictability accuracy. Using R’s glmnet package, select the regulation parameter lambda that
#better predict house prices, then fit the model and obtain the set of attributes that are associated
#with said lambda. How does your answer above changes? What is the role of lambda?
